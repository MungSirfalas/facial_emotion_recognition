# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from keras.models import load_model
from keras.utils import img_to_array
from keras.preprocessing import image

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %run "/content/gdrive/MyDrive/Colab Notebooks/UNIR/2_Cuatrimestre/TFM/3_utils/PY_utils.ipynb"

# %%
# define model names and root path
model_list = ["1_fer_da", "2_fer_sda", "3_aux_da", "4_aux_sda"]
ROOT = "/content/gdrive/MyDrive/Colab Notebooks/UNIR/2_Cuatrimestre/TFM/1_modeling/"

# %% [markdown]
# ### 1. Learning curves

# %%
for model_name in model_list:
    learning_curve_from_file(ROOT, model_name)
